# %% [markdown]
# # About this project:
#
# This project aims to train a neural network model to identify the presence of COVID-19 from images of Chest X-Rays. A model that works well would be useful for accelerating the identification of infected individuals, especially in countries where hospitals are overwhelmed and can benefit from streamlining the testing process.
#
#
# ## Dataset information:
#
#
# The dataset was downloaded from Kaggle: https://www.kaggle.com/praveengovi/coronahack-chest-xraydataset
#
#
# ## Content
#
# The dataset contains ~5800 jpeg images of Chest X-Rays of Healthy patients, as well as patients affected with Pneumonia. The pneumonia X-Rays contain cases of bacterial infections as well as viral infections, such as SARS (Severe Acute Respiratory Syndrome ) ,Streptococcus & ARDS (Acute Respiratory Distress Syndrome).
#
#
# ## Acknowledgements
#
# This analysis is made possible by the dataset compiled by Joseph Paul Cohen. Postdoctoral Fellow, Mila, University of Montreal.
#
# Original Source :- https://github.com/ieee8023/covid-chestxray-dataset

# %% [markdown]
# # Import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import copy
import PIL
import tensorflow as tf
from sklearn.metrics import plot_confusion_matrix, confusion_matrix

#For organizing image folders and image analysis

import shutil
import os
from sklearn.model_selection import train_test_split
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import array_to_img

#Hyperparameter tuning
import kerastuner as kt
import math

#Model building
from tensorflow import keras
from tensorflow.keras import layers
from keras import Sequential
from keras.layers import Conv2D, Dense, Flatten, Dropout, BatchNormalization, MaxPool2D
from keras.models import Sequential, load_model
from keras.metrics import AUC, Precision, Recall
from keras.optimizers import Adam

# %% [markdown]
# # Ensure we use a GPU for faster neural network training

# %% [markdown]
# Note: For this notebook we create a virtual environment with the tensorflow-gpu package instead of the usual tensorflow. This ensures GPU usage for training instead of CPU.
#
# Documentation: https://www.tensorflow.org/install/gpu

# %%
from tensorflow.python.client import device_lib

print('Making sure GPU is available:')
print("GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
print('GPU Name:', tf.config.list_physical_devices('GPU'))
# Out:
# Making sure GPU is available:
# GPUs Available:  1
# GPU Name: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# GPU usage resulted in ~40s per epoch compared to 26 mins with CPU!

# %% [markdown]
# # Import data

# %%
# os.mkdir('./Data/')

df = pd.read_csv('https://github.com/Kesterchia/Classifying-Chest-X-Rays/blob/main/Data/Chest_xray_Corona_Metadata.csv?raw=True', index_col = 0)

df_train = df[df['Dataset_type'] == 'TRAIN']
df_test = df[df['Dataset_type'] == 'TEST']

print('Training data shape:', df_train.shape)
print('Testing data shape:', df_test.shape)

#Looking at metadata:

df_train.head()
# Out:
# Training data shape: (5286, 5)
# Testing data shape: (624, 5)
#     X_ray_image_name   Label Dataset_type Label_2_Virus_category  \
# 0  IM-0128-0001.jpeg  Normal        TRAIN                    NaN
# 1  IM-0127-0001.jpeg  Normal        TRAIN                    NaN
# 2  IM-0125-0001.jpeg  Normal        TRAIN                    NaN
# 3  IM-0122-0001.jpeg  Normal        TRAIN                    NaN
# 4  IM-0119-0001.jpeg  Normal        TRAIN                    NaN
#
#   Label_1_Virus_category
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN

# %%
#The dataset also contains a csv file of the summary counts:

summary = pd.read_csv('https://github.com/Kesterchia/Classifying-Chest-X-Rays/blob/main/Data/Chest_xray_Corona_dataset_Summary.csv?raw=True', index_col = 0)
summary
# Out:
#       Label Label_1_Virus_category Label_2_Virus_category  Image_Count
# 0    Normal                    NaN                    NaN         1576
# 1  Pnemonia         Stress-Smoking                   ARDS            2
# 2  Pnemonia                  Virus                    NaN         1493
# 3  Pnemonia                  Virus               COVID-19           58
# 4  Pnemonia                  Virus                   SARS            4
# 5  Pnemonia               bacteria                    NaN         2772
# 6  Pnemonia               bacteria          Streptococcus            5

# %% [markdown]
# Some of the rows have too little data and will simply be dropped from the analysis:

# %%
#Drop unwanted rows:
summary.drop(axis = 0, index = [1,4,6])
# Out:
#       Label Label_1_Virus_category Label_2_Virus_category  Image_Count
# 0    Normal                    NaN                    NaN         1576
# 2  Pnemonia                  Virus                    NaN         1493
# 3  Pnemonia                  Virus               COVID-19           58
# 5  Pnemonia               bacteria                    NaN         2772

# %% [markdown]
# All the images will be used for analysis except the non-viral, Stress-Smoking images, as there are only 2 of those.
#
# The dataset is also very imbalanced with only 58 images for the COVID-19 category. Class weights will be implemented later on to address the issue.

# %% [markdown]
# # Preparing the image data by rearranging the directories:

# %% [markdown]
# ### Making new folders for Healthy (Pneumonia-free) X-Rays:

# %%
#Get list of all filenames

all_filenames_test = os.listdir('./Pictures/test')
all_filenames_train = os.listdir('./Pictures/train')

#Get list of filenames for the 'Normal' or healthy X-rays

normal_filenames_test = list(df_test[df_test['Label'] == 'Normal']['X_ray_image_name'])
normal_filenames_train = list(df_train[df_train['Label'] == 'Normal']['X_ray_image_name'])

print('No. of Normal X-rays (training):',len(normal_filenames_train))
print('No. of Normal X-rays (testing):',len(normal_filenames_test))
# Out:
# No. of Normal X-rays (training): 1342
# No. of Normal X-rays (testing): 234

# %%
#Move files into new folder (testing)

'''
#os.makedirs('./Pictures/test/normal')


for filename in normal_filenames_test:
    shutil.move(src = './Pictures/test/{}'.format(filename),
                dst = './Pictures/test/normal/{}'.format(filename)
               )
'''
    
#Move files into new folder (training)

'''
os.makedirs('./Pictures/train/normal')

for filename in normal_filenames_train:
    shutil.move(src = './Pictures/train/{}'.format(filename),
                dst = './Pictures/train/normal/{}'.format(filename)
               )               
'''
# Out:
# "\nos.makedirs('./Pictures/train/normal')\n\nfor filename in normal_filenames_train:\n    shutil.move(src = './Pictures/train/{}'.format(filename),\n                dst = './Pictures/train/normal/{}'.format(filename)\n               )               \n"

# %% [markdown]
# ### Making new folders for Pneumonia (bacterial) infections:

# %%
#Get list of filenames for the bacterial infection X-rays

bacteria_filenames_test = list(df_test[df_test['Label_1_Virus_category'] == 'bacteria']['X_ray_image_name'])
bacteria_filenames_train = list(df_train[df_train['Label_1_Virus_category'] == 'bacteria']['X_ray_image_name'])

print('No. of Bacterial Infection X-rays (training):',len(bacteria_filenames_train))
print('No. of Bacterial Infection X-rays (testing):',len(bacteria_filenames_test))
# Out:
# No. of Bacterial Infection X-rays (training): 2535
# No. of Bacterial Infection X-rays (testing): 242

# %%
#Move files into new folder (testing)

'''
os.makedirs('./Pictures/test/bacteria')


for filename in bacteria_filenames_test:
    shutil.move(src = './Pictures/test/{}'.format(filename),
                dst = './Pictures/test/bacteria/{}'.format(filename)
               )

'''

#Move files into new folder (training)

'''
os.makedirs('./Pictures/train/bacteria')

for filename in bacteria_filenames_train:
    shutil.move(src = './Pictures/train/{}'.format(filename),
                dst = './Pictures/train/bacteria/{}'.format(filename)
               )         
'''
# Out:
# "\nos.makedirs('./Pictures/train/bacteria')\n\nfor filename in bacteria_filenames_train:\n    shutil.move(src = './Pictures/train/{}'.format(filename),\n                dst = './Pictures/train/bacteria/{}'.format(filename)\n               )         \n"

# %% [markdown]
# ### Making new folder for Pneumonia (Viral, COVID-19) infections:

# %% [markdown]
# The original testing folder has no Covid-19 labelled images, so we will move some there from the training folder

# %%
#Get list of filenames for the bacterial infection X-rays

covid_filenames_test = list(df_test[df_test['Label_2_Virus_category'] == 'COVID-19']['X_ray_image_name'])
covid_filenames_train = list(df_train[df_train['Label_2_Virus_category'] == 'COVID-19']['X_ray_image_name'])

print('No. of COVID-19 Infection X-rays (training):',len(covid_filenames_train))
print('No. of COVID-19 Infection X-rays (testing):',len(covid_filenames_test))
# Out:
# No. of COVID-19 Infection X-rays (training): 58
# No. of COVID-19 Infection X-rays (testing): 0

# %%
#Moving covid-19 x-ray files to new folders:


#Move files into new folder (testing)

'''
# os.makedirs('./Pictures/test/covid-19')

for filename in covid_filenames_train[:8]:
    shutil.move(src = './Pictures/train/{}'.format(filename),
                dst = './Pictures/test/covid-19/'
               )
'''



#Move files into new folder (training)

'''
os.makedirs('./Pictures/train/covid-19')

for filename in covid_filenames_train[8:]:
    shutil.move(src = './Pictures/train/{}'.format(filename),
                dst = './Pictures/train/covid-19/'
               )         
'''
# Out:
# "\nos.makedirs('./Pictures/train/covid-19')\n\nfor filename in covid_filenames_train[8:]:\n    shutil.move(src = './Pictures/train/{}'.format(filename),\n                dst = './Pictures/train/covid-19/'\n               )         \n"

# %%
#Get list of filenames for the bacterial infection X-rays

virus_noncovid_filenames_test = list(df_test.loc[(df_test['Label_2_Virus_category'] != 'COVID-19' )
                                        & 
                                        (df_test['Label_1_Virus_category'] == 'Virus')
                                        ]['X_ray_image_name']
                           )

virus_noncovid_filenames_train = list(df_train.loc[(df_train['Label_2_Virus_category'] != 'COVID-19' )
                                        & 
                                        (df_train['Label_1_Virus_category'] == 'Virus')
                                        ]['X_ray_image_name']
                           )

print('No. of Viral Infection X-rays (training):',len(virus_noncovid_filenames_train))
print('No. of Viral Infection X-rays (testing):',len(virus_noncovid_filenames_test))
# Out:
# No. of Viral Infection X-rays (training): 1349
# No. of Viral Infection X-rays (testing): 148

# %%
#Move files into new folder (testing)

'''
os.makedirs('./Pictures/test/virus(non-covid)')

for filename in virus_noncovid_filenames_test:
    shutil.move(src = './Pictures/test/{}'.format(filename),
                dst = './Pictures/test/virus(non-covid)/'
               )
'''

#Move files into new folder (training)

'''
os.makedirs('./Pictures/train/virus(non-covid)')

for filename in virus_noncovid_filenames_train:
    shutil.move(src = './Pictures/train/{}'.format(filename),
                dst = './Pictures/train/virus(non-covid)/'
               )         
'''
# Out:
# "\nos.makedirs('./Pictures/train/virus(non-covid)')\n\nfor filename in virus_noncovid_filenames_train:\n    shutil.move(src = './Pictures/train/{}'.format(filename),\n                dst = './Pictures/train/virus(non-covid)/'\n               )         \n"

# %% [markdown]
# This is what the data folder structure for the pictures looks like now:

# %%
#Visualize the picture folder

def list_files(startpath):
    for root, dirs, files in os.walk(startpath):
        level = root.replace(startpath, '').count(os.sep)
        indent = ' ' * 4 * (level)
        print('{}{}/'.format(indent, os.path.basename(root)))
        subindent = ' ' * 4 * (level + 1)
                   
list_files('./Pictures')
# Out:
# Pictures/
#     test/
#         bacteria/
#         covid-19/
#         normal/
#         virus(non-covid)/
#     train/
#         bacteria/
#         covid-19/
#         normal/
#         virus(non-covid)/

# %% [markdown]
# Note: There were 25 images in the training set with no metadata. They were deleted from the folder.

# %% [markdown]
# # Loading an example image

# %%
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import array_to_img

# %% [markdown]
# ### Seeing some example images:

# %%
#Getting some sample images

normal = df_train[df_train['Label'] == 'Normal']['X_ray_image_name'].iloc[0]
bacteria = df_train[df_train['Label_1_Virus_category'] == 'bacteria']['X_ray_image_name'].iloc[0]
virus_covid = df_train[df_train['Label_2_Virus_category'] == 'COVID-19']['X_ray_image_name'].iloc[10]
virus_noncovid = df_train[(df_train['Label_2_Virus_category'] != 'COVID-19')
                          &
                          (df_train['Label_1_Virus_category'] == 'Virus')]['X_ray_image_name'].iloc[0]


covid_img = load_img('./Pictures/train/covid-19/{}'.format(virus_covid))
virus_noncovid_img = load_img('./Pictures/train/virus(non-covid)/{}'.format(virus_noncovid))
bacteria_img = load_img('./Pictures/train/bacteria/{}'.format(bacteria))
normal_img = load_img('./Pictures/train/normal/{}'.format(normal))



#Plotting the images

fig, ax = plt.subplots(nrows = 2, ncols = 2, figsize = (14,14))



ax[0][0].imshow(covid_img)
ax[0][0].set_title('Viral infection (Covid-19)')

ax[0][1].imshow(virus_noncovid_img)
ax[0][1].set_title('Viral infection (Non-covid)')

ax[1][0].imshow(bacteria_img)
ax[1][0].set_title('Bacterial infection')

ax[1][1].imshow(normal_img)
ax[1][1].set_title('Healthy')


plt.show()

# %% [markdown]
# # Doing image augmentation

# %% [markdown]
# There are only 58 images of COVID-19 labelled X-rays in our dataset which is tragic, so we will attempt to some image augmentation.
#
# Here we will try to artificially generate images so we can have a larger training dataset. First we decide what kind of image transformations will be appropriate, and then proceed with the generation.

# %%
#Import libraries

from keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing.image import img_to_array, array_to_img

# %% [markdown]
# ### Horizontal image shifting

# %%
#Convert the data to a numpy array

img_array = img_to_array(covid_img)

img_array.shape
# Out:
# (1024, 1024, 3)

# %%
#Expand the dimensions by 1 to fit tensorflow's requirements

img_array_exp = np.expand_dims(img_array, 0)

img_array_exp.shape
# Out:
# (1, 1024, 1024, 3)

# %%
imagegen = ImageDataGenerator(width_shift_range = 0.2)

iterator = imagegen.flow(img_array_exp)

# %%
#Plotting a few example images of horizontal shifting

fig, ax = plt.subplots(nrows = 1, ncols =4, 
                           figsize = (20,5))

for i in range(4):

    ax[i].imshow(array_to_img(x = iterator.next()[0],
                             scale = False),
                 aspect = 'auto')
    
fig.suptitle('Horizontal image shifting')
plt.show()

# %% [markdown]
# ### Vertical image shifting

# %%
imagegen = ImageDataGenerator(height_shift_range = 0.2)

iterator = imagegen.flow(img_array_exp)

# %%
#Plotting a few example images of horizontal shifting

fig, ax = plt.subplots(nrows = 1, ncols =4, 
                           figsize = (20,5))

for i in range(4):

    ax[i].imshow(array_to_img(x = iterator.next()[0],
                             scale = False),
                 aspect = 'auto')
    
fig.suptitle('Vertical image shifting')
plt.show()

# %% [markdown]
# ### Horizontal flipping:

# %%
imagegen = ImageDataGenerator(horizontal_flip = True)

iterator = imagegen.flow(img_array_exp)

# %%
#Plotting a few example images of horizontal shifting

fig, ax = plt.subplots(nrows = 1, ncols =4, 
                           figsize = (20,5))

for i in range(4):

    ax[i].imshow(array_to_img(x = iterator.next()[0],
                             scale = False),
                 aspect = 'auto')
    
fig.suptitle('Horizontal flipping of images')
plt.show()

# %% [markdown]
# ### Vertical flipping:

# %% [markdown]
# Vertical flipping would not be realistic for X-ray images so we exclude that. Therefore we will use the previous 3 image transformations to generate new data.

# %% [markdown]
# # Load images into keras image generators

# %%
#Prepare our generator

generator = ImageDataGenerator(width_shift_range = 0.2,
                               height_shift_range = 0.2,
                               horizontal_flip = True)

# %%
#Attach generator to the directories

train_generator = generator.flow_from_directory(directory = './Pictures/train',
                                                class_mode = 'categorical',
                                                color_mode = 'grayscale',
                                                batch_size = 16)

test_generator = generator.flow_from_directory(directory = './Pictures/test',
                                                class_mode = 'categorical',
                                                color_mode = 'grayscale')
# Out:
# Found 5276 images belonging to 4 classes.
# Found 632 images belonging to 4 classes.

# %%
#Also prepare a static dataset

from keras.preprocessing import image_dataset_from_directory

training_ds = image_dataset_from_directory(directory = './Pictures/train',
                                           label_mode = 'categorical',
                                           color_mode = 'grayscale',
                                           batch_size = 8)
testing_ds = image_dataset_from_directory(directory = './Pictures/test',
                                           label_mode = 'categorical',
                                           color_mode = 'grayscale')
# Out:
# Found 5276 files belonging to 4 classes.
# Found 632 files belonging to 4 classes.

# %% [markdown]
# ### Preparing class weights for model fitting:

# %%
#Put the class counts in to a dictionary:

classes = os.listdir('./Pictures/train')
classes.remove('desktop.ini')

class_count = dict()

#First we see a count of our classes:
for i in classes:
    class_count[i] = len(os.listdir('./Pictures/train/{}'.format(i)))

class_count
# Out:
# {'bacteria': 2536, 'covid-19': 51, 'normal': 1343, 'virus(non-covid)': 1350}

# %%
#Compute class weights as an inverse of the count:

total_sum = sum(class_count.values())

class_weights = {label: 1/(count/total_sum) for label, count in enumerate(class_count.values())}

class_weights_names = {list(class_count.keys())[label]: 1/(count/total_sum) for label, count in enumerate(class_count.values())}

#Check output:

class_weights_names
# Out:
# {'bacteria': 2.082018927444795,
#  'covid-19': 103.52941176470588,
#  'normal': 3.9314966492926287,
#  'virus(non-covid)': 3.911111111111111}

# %% [markdown]
# Weight for covid-19 images is a little high as the direct reciprocal of the count, so we adjust it downwards a little

# %%
class_weights[1] = 20.0

class_weights

#Note: The label keys must be in integers instead of the class names so it can be used for model training later
# Out:
# {0: 2.082018927444795, 1: 20.0, 2: 3.9314966492926287, 3: 3.911111111111111}

# %% [markdown]
# # Constructing the model

# %% [markdown]
# ### Using Keras Tuner to tune model hyperparameters:

# %% [markdown]
# First we define a function that builds a compiled model, which takes in one 'hyperparameter' argument:

# %%
def build_model(hp):
    
    #Instantiate model:
    model = keras.Sequential()
    
    #Tune first layer:
    
    filters_choices1 = hp.Choice('filters_stage1', [8,16,32,64])
    
    model.add(Conv2D(filters_choices1, 
                     kernel_size = (5,5), 
                 input_shape = (256,256,1), #Provide input shape for first layer!
                 #kernel_regularizer=keras.regularizers.l1(0.01), #Regularization to prevent overfitting
                 activation = 'relu', 
                 padding = 'same')) #Zero pad the borders 
    
    
    model.add(MaxPool2D(pool_size = (2,2),
                    strides = (2,2) )) #Pooling to accelerate learning

    model.add(Conv2D(filters_choices1,
                     kernel_size = (5,5), 
                     #kernel_regularizer=keras.regularizers.l1(0.01),
                     activation = 'relu',
                     padding = 'valid'))

    model.add(MaxPool2D(pool_size = (2,2),
                    strides = (2,2) )) #Pooling to accelerate learning

    
    filters_choices2 = hp.Choice('filters_stage2', [16,32,64,128])
    model.add(Conv2D(filters_choices2, 
                     kernel_size = (5,5), 
                     #kernel_regularizer=keras.regularizers.l1(0.01),
                     activation = 'relu',
                     padding = 'valid'))
    model.add(Flatten())
    
    dense_choices = hp.Choice('units',[20,40,60,80])
    model.add(Dense(dense_choices, activation = 'relu'))
    
    model.add(Dense(4, activation = 'softmax'))
    
    model.compile(optimizer = Adam(hp.Choice('learning_rate', [0.01,0.001,0.0001,0.00001,0.000001])
                                  ),
                  loss = tf.keras.losses.CategoricalCrossentropy(),
                  metrics = ['accuracy', AUC(), Precision(), Recall()])
    
    return model

# %% [markdown]
# We instantiate the tuner, in this case we use the Hyperband algorithm. There are other built-in algorithms available like Bayesian Optimization and Random Search. The Hyperband algorithm quickly discards poor-performing models and runs more epochs for more promising ones:

# %%
#Instantiate tuner

tuner = kt.Hyperband(build_model,
                     objective = 'accuracy', 
                     max_epochs = 100,
                     hyperband_iterations = 3,
                     project_name = 'Keras Tuner',
                    )

#Create an early stopping callback to stop model training if loss stagnates

stopper_callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=3)
# Out:
# INFO:tensorflow:Reloading Oracle from existing project .\Keras Tuner\oracle.json
# INFO:tensorflow:Reloading Tuner from .\Keras Tuner\tuner0.json

# %% [markdown]
# The model has been tuned and the tuner saved locally. Tuning took about 5-6 hours.

# %%
'''
#Begin tuning hyperparameters!

tuner.search(train_generator, 
                     #callbacks = [stopper_callback], #seems to be getting some error with the callback
                     epochs = 50, 
                     class_weight = class_weights)
'''
# Out:
# '\n#Begin tuning hyperparameters!\n\ntuner.search(train_generator, \n                     #callbacks = [stopper_callback], #seems to be getting some error with the callback\n                     epochs = 50, \n                     class_weight = class_weights)\n'

# %%
best_params = tuner.get_best_hyperparameters()[0].values

#Print the best parameters found by Hyperband:

print('Best parameters:', '\n')
print('No. of convolution filters in stage 1:', best_params['filters_stage1'])
print('No. of convolution filters in stage 2:', best_params['filters_stage2'])
print('No. of units in second-last Dense layer:', best_params['units'])
print('Base learning rate for Adam optimizer', best_params['learning_rate'])
# Out:
# Best parameters:
#
# No. of convolution filters in stage 1: 32
# No. of convolution filters in stage 2: 128
# No. of units in second-last Dense layer: 80
# Base learning rate for Adam optimizer 0.0001

# %% [markdown]
# ### In the case of loading a previously saved model:

# %%
model = load_model('./Models/Model_seven_with_augmentation_tuned')

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 256, 256, 32)      832
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 128, 128, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 124, 124, 32)      25632
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 62, 62, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 58, 58, 128)       102528
# _________________________________________________________________
# flatten (Flatten)            (None, 430592)            0
# _________________________________________________________________
# dense (Dense)                (None, 80)                34447440
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 324
# =================================================================
# Total params: 34,576,756
# Trainable params: 34,576,756
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### In the case of constructing a new model with tuned hyperparameters:

# %%
#model = tuner.get_best_models()[0]

#model.summary()

# %% [markdown]
# ### Creating a scheduler so the learning rate decays as the model learns

# %% [markdown]
# Adam already adjusts per-parameter learning rate during training, but the base learning rate can also be set to decay. The base will be the maximum learning rate limit that Adam allocates per parameter.

# %%
#Create a scheduler to adjust learning rate across epochs

#Define a function to apply a time-based reciprocal decay to learning rate
#after 100 epochs

def decay(epoch, lr, decayspeed = 0.1):
    if epoch < 20:
        return lr
    else:
        return lr/(1+(decayspeed*epoch))

#Create a scheduler

from keras.callbacks import LearningRateScheduler

scheduler = LearningRateScheduler(decay)

# %%
#Fit the model using augmented images and a scheduler to decay learning rate

'''
history = model.fit(x = train_generator, 
                    epochs = 500, 
                    steps_per_epoch= None,
                    callbacks = scheduler,
                    class_weight = class_weights
                   )
'''
# Out:
# Epoch 1/500
# 330/330 [==============================] - 41s 125ms/step - loss: 1.7475 - accuracy: 0.7530 - auc: 0.9371 - precision: 0.7720 - recall: 0.7206
# Epoch 2/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.6858 - accuracy: 0.7576 - auc: 0.9396 - precision: 0.7785 - recall: 0.7250
# Epoch 3/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.7395 - accuracy: 0.7559 - auc: 0.9388 - precision: 0.7782 - recall: 0.7235
# Epoch 4/500
# 330/330 [==============================] - 41s 125ms/step - loss: 1.6403 - accuracy: 0.7616 - auc: 0.9415 - precision: 0.7804 - recall: 0.7356
# Epoch 5/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.6023 - accuracy: 0.7663 - auc: 0.9439 - precision: 0.7802 - recall: 0.7455
# Epoch 6/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.6739 - accuracy: 0.7557 - auc: 0.9406 - precision: 0.7744 - recall: 0.7273
# Epoch 7/500
# 330/330 [==============================] - 41s 125ms/step - loss: 1.6724 - accuracy: 0.7557 - auc: 0.9411 - precision: 0.7785 - recall: 0.7322
# Epoch 8/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.6311 - accuracy: 0.7604 - auc: 0.9428 - precision: 0.7803 - recall: 0.7369
# Epoch 9/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.5847 - accuracy: 0.7636 - auc: 0.9437 - precision: 0.7827 - recall: 0.7426
# Epoch 10/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.5537 - accuracy: 0.7697 - auc: 0.9468 - precision: 0.7888 - recall: 0.7477
# Epoch 11/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.5944 - accuracy: 0.7625 - auc: 0.9439 - precision: 0.7825 - recall: 0.7418
# Epoch 12/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.5771 - accuracy: 0.7676 - auc: 0.9449 - precision: 0.7828 - recall: 0.7460
# Epoch 13/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.6131 - accuracy: 0.7600 - auc: 0.9438 - precision: 0.7785 - recall: 0.7375
# Epoch 14/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.5415 - accuracy: 0.7640 - auc: 0.9462 - precision: 0.7822 - recall: 0.7432
# Epoch 15/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.5417 - accuracy: 0.7657 - auc: 0.9462 - precision: 0.7818 - recall: 0.7491
# Epoch 16/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.5395 - accuracy: 0.7722 - auc: 0.9471 - precision: 0.7913 - recall: 0.7553
# Epoch 17/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.6169 - accuracy: 0.7646 - auc: 0.9443 - precision: 0.7829 - recall: 0.7388
# Epoch 18/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.5225 - accuracy: 0.7762 - auc: 0.9477 - precision: 0.7919 - recall: 0.7566
# Epoch 19/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.5327 - accuracy: 0.7762 - auc: 0.9466 - precision: 0.7912 - recall: 0.7568
# Epoch 20/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.5125 - accuracy: 0.7756 - auc: 0.9480 - precision: 0.7923 - recall: 0.7532
# Epoch 21/500
# 330/330 [==============================] - 41s 125ms/step - loss: 1.4088 - accuracy: 0.7868 - auc: 0.9527 - precision: 0.8007 - recall: 0.7701
# Epoch 22/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.4173 - accuracy: 0.7854 - auc: 0.9539 - precision: 0.7967 - recall: 0.77334s - loss: 1.4113 - accuracy: 0.7870 - auc: 0.9545
# Epoch 23/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3947 - accuracy: 0.7870 - auc: 0.9540 - precision: 0.7970 - recall: 0.7716
# Epoch 24/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3907 - accuracy: 0.7875 - auc: 0.9532 - precision: 0.7995 - recall: 0.7724
# Epoch 25/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3794 - accuracy: 0.7923 - auc: 0.9549 - precision: 0.8021 - recall: 0.7760
# Epoch 26/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3844 - accuracy: 0.7911 - auc: 0.9553 - precision: 0.7998 - recall: 0.7775
# Epoch 27/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3832 - accuracy: 0.7854 - auc: 0.9544 - precision: 0.7969 - recall: 0.7712
# Epoch 28/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3820 - accuracy: 0.7889 - auc: 0.9544 - precision: 0.7994 - recall: 0.7741
# Epoch 29/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3621 - accuracy: 0.7906 - auc: 0.9555 - precision: 0.8035 - recall: 0.7782
# Epoch 30/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3674 - accuracy: 0.7902 - auc: 0.9552 - precision: 0.8002 - recall: 0.7758
# Epoch 31/500
# 330/330 [==============================] - 40s 123ms/step - loss: 1.3891 - accuracy: 0.7911 - auc: 0.9541 - precision: 0.8012 - recall: 0.7777
# Epoch 32/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3671 - accuracy: 0.7911 - auc: 0.9550 - precision: 0.8034 - recall: 0.7786
# Epoch 33/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3799 - accuracy: 0.7885 - auc: 0.9542 - precision: 0.7979 - recall: 0.7762
# Epoch 34/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3588 - accuracy: 0.7911 - auc: 0.9554 - precision: 0.8020 - recall: 0.7775
# Epoch 35/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3570 - accuracy: 0.7909 - auc: 0.9551 - precision: 0.8017 - recall: 0.7754
# Epoch 36/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.4090 - accuracy: 0.7834 - auc: 0.9532 - precision: 0.7938 - recall: 0.7705
# Epoch 37/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3710 - accuracy: 0.7945 - auc: 0.9551 - precision: 0.8035 - recall: 0.7782
# Epoch 38/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3515 - accuracy: 0.7889 - auc: 0.9553 - precision: 0.7991 - recall: 0.7750
# Epoch 39/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3614 - accuracy: 0.7926 - auc: 0.9558 - precision: 0.8030 - recall: 0.7803
# Epoch 40/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.4041 - accuracy: 0.7868 - auc: 0.9535 - precision: 0.7984 - recall: 0.7733
# Epoch 41/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3432 - accuracy: 0.7947 - auc: 0.9562 - precision: 0.8040 - recall: 0.7784
# Epoch 42/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3746 - accuracy: 0.7898 - auc: 0.9547 - precision: 0.8010 - recall: 0.7775
# Epoch 43/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3476 - accuracy: 0.7947 - auc: 0.9563 - precision: 0.8036 - recall: 0.7826
# Epoch 44/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3713 - accuracy: 0.7870 - auc: 0.9548 - precision: 0.7980 - recall: 0.7735
# Epoch 45/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3614 - accuracy: 0.7921 - auc: 0.9553 - precision: 0.8025 - recall: 0.7784
# Epoch 46/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3892 - accuracy: 0.7889 - auc: 0.9536 - precision: 0.7998 - recall: 0.7746
# Epoch 47/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3816 - accuracy: 0.7887 - auc: 0.9541 - precision: 0.7994 - recall: 0.7735
# Epoch 48/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.4005 - accuracy: 0.7877 - auc: 0.9544 - precision: 0.7967 - recall: 0.7733
# Epoch 49/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3823 - accuracy: 0.7868 - auc: 0.9548 - precision: 0.7980 - recall: 0.7735
# Epoch 50/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.4032 - accuracy: 0.7925 - auc: 0.9546 - precision: 0.8025 - recall: 0.7777
# Epoch 51/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3568 - accuracy: 0.7906 - auc: 0.9558 - precision: 0.8013 - recall: 0.7782
# Epoch 52/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3681 - accuracy: 0.7959 - auc: 0.9561 - precision: 0.8071 - recall: 0.7801
# Epoch 53/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3931 - accuracy: 0.7913 - auc: 0.9547 - precision: 0.8012 - recall: 0.7790
# Epoch 54/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3834 - accuracy: 0.7904 - auc: 0.9552 - precision: 0.8022 - recall: 0.7777
# Epoch 55/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3803 - accuracy: 0.7930 - auc: 0.9554 - precision: 0.8038 - recall: 0.7798
# Epoch 56/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3908 - accuracy: 0.7906 - auc: 0.9542 - precision: 0.7984 - recall: 0.7739
# Epoch 57/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3830 - accuracy: 0.7883 - auc: 0.9550 - precision: 0.7989 - recall: 0.7771
# Epoch 58/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3861 - accuracy: 0.7904 - auc: 0.9542 - precision: 0.8007 - recall: 0.7769
# Epoch 59/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3588 - accuracy: 0.7928 - auc: 0.9549 - precision: 0.8045 - recall: 0.7801
# Epoch 60/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3953 - accuracy: 0.7900 - auc: 0.9547 - precision: 0.7997 - recall: 0.7748
# Epoch 61/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3477 - accuracy: 0.7913 - auc: 0.9559 - precision: 0.8001 - recall: 0.7777
# Epoch 62/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3506 - accuracy: 0.7909 - auc: 0.9556 - precision: 0.8013 - recall: 0.7775
# Epoch 63/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3701 - accuracy: 0.7885 - auc: 0.9547 - precision: 0.7987 - recall: 0.7722
# Epoch 64/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3544 - accuracy: 0.7909 - auc: 0.9554 - precision: 0.8034 - recall: 0.7769
# Epoch 65/500
# 330/330 [==============================] - 42s 126ms/step - loss: 1.3478 - accuracy: 0.7923 - auc: 0.9565 - precision: 0.8025 - recall: 0.7792
# Epoch 66/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.4027 - accuracy: 0.7957 - auc: 0.9548 - precision: 0.8038 - recall: 0.7837
# Epoch 67/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3652 - accuracy: 0.7885 - auc: 0.9547 - precision: 0.8008 - recall: 0.7735
# Epoch 68/500
# 330/330 [==============================] - 41s 125ms/step - loss: 1.3922 - accuracy: 0.7864 - auc: 0.9536 - precision: 0.7940 - recall: 0.7729
# Epoch 69/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3640 - accuracy: 0.7925 - auc: 0.9543 - precision: 0.8012 - recall: 0.7760
# Epoch 70/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3623 - accuracy: 0.7887 - auc: 0.9556 - precision: 0.8004 - recall: 0.7750
# Epoch 71/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3664 - accuracy: 0.7896 - auc: 0.9552 - precision: 0.7975 - recall: 0.7758
# Epoch 72/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3744 - accuracy: 0.7909 - auc: 0.9545 - precision: 0.8000 - recall: 0.7773
# Epoch 73/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3830 - accuracy: 0.7889 - auc: 0.9549 - precision: 0.8004 - recall: 0.7769
# Epoch 74/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3847 - accuracy: 0.7921 - auc: 0.9544 - precision: 0.8032 - recall: 0.7790
# Epoch 75/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3893 - accuracy: 0.7904 - auc: 0.9548 - precision: 0.8013 - recall: 0.7752
# Epoch 76/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3717 - accuracy: 0.7925 - auc: 0.9553 - precision: 0.8045 - recall: 0.7798
# Epoch 77/500
# 330/330 [==============================] - 41s 125ms/step - loss: 1.3664 - accuracy: 0.7898 - auc: 0.9545 - precision: 0.7998 - recall: 0.7769
# Epoch 78/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3677 - accuracy: 0.7913 - auc: 0.9551 - precision: 0.8020 - recall: 0.7775
# Epoch 79/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3966 - accuracy: 0.7925 - auc: 0.9544 - precision: 0.8025 - recall: 0.7781
# Epoch 80/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3654 - accuracy: 0.7928 - auc: 0.9554 - precision: 0.8055 - recall: 0.7784
# Epoch 81/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3667 - accuracy: 0.7892 - auc: 0.9556 - precision: 0.8004 - recall: 0.7765
# Epoch 82/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3422 - accuracy: 0.7909 - auc: 0.9563 - precision: 0.8000 - recall: 0.7771
# Epoch 83/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3644 - accuracy: 0.7883 - auc: 0.9550 - precision: 0.7996 - recall: 0.7739
# Epoch 84/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3775 - accuracy: 0.7919 - auc: 0.9548 - precision: 0.8019 - recall: 0.7781
# Epoch 85/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3597 - accuracy: 0.7930 - auc: 0.9558 - precision: 0.8033 - recall: 0.7801
# Epoch 86/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3664 - accuracy: 0.7930 - auc: 0.9546 - precision: 0.8028 - recall: 0.7784
# Epoch 87/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3664 - accuracy: 0.7883 - auc: 0.9546 - precision: 0.8006 - recall: 0.7739
# Epoch 88/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3616 - accuracy: 0.7970 - auc: 0.9564 - precision: 0.8059 - recall: 0.7820
# Epoch 89/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3552 - accuracy: 0.7870 - auc: 0.9553 - precision: 0.7973 - recall: 0.7726
# Epoch 90/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3777 - accuracy: 0.7898 - auc: 0.9546 - precision: 0.7985 - recall: 0.7760
# Epoch 91/500
# 330/330 [==============================] - 41s 125ms/step - loss: 1.3787 - accuracy: 0.7879 - auc: 0.9547 - precision: 0.7981 - recall: 0.7708
# Epoch 92/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3844 - accuracy: 0.7911 - auc: 0.9542 - precision: 0.8024 - recall: 0.7758
# Epoch 93/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3784 - accuracy: 0.7887 - auc: 0.9550 - precision: 0.7993 - recall: 0.7765
# Epoch 94/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3867 - accuracy: 0.7877 - auc: 0.9541 - precision: 0.7978 - recall: 0.7724
# Epoch 95/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3746 - accuracy: 0.7896 - auc: 0.9547 - precision: 0.8017 - recall: 0.7769
# Epoch 96/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3850 - accuracy: 0.7900 - auc: 0.9550 - precision: 0.8014 - recall: 0.7733
# Epoch 97/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3689 - accuracy: 0.7877 - auc: 0.9551 - precision: 0.7997 - recall: 0.7720
# Epoch 98/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3907 - accuracy: 0.7898 - auc: 0.9545 - precision: 0.8004 - recall: 0.7762
# Epoch 99/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3653 - accuracy: 0.7877 - auc: 0.9555 - precision: 0.8004 - recall: 0.7762
# Epoch 100/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3547 - accuracy: 0.7898 - auc: 0.9563 - precision: 0.7991 - recall: 0.7763
# Epoch 101/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3693 - accuracy: 0.7883 - auc: 0.9546 - precision: 0.7978 - recall: 0.7739
# Epoch 102/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3814 - accuracy: 0.7915 - auc: 0.9549 - precision: 0.8007 - recall: 0.7775
# Epoch 103/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3664 - accuracy: 0.7913 - auc: 0.9556 - precision: 0.8013 - recall: 0.7781
# Epoch 104/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3806 - accuracy: 0.7887 - auc: 0.9545 - precision: 0.8006 - recall: 0.77313s - loss: 1.3870 - accuracy: 0.7880 - auc: 0.9543 - p
# Epoch 105/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3940 - accuracy: 0.7828 - auc: 0.9529 - precision: 0.7942 - recall: 0.7701
# Epoch 106/500
# 330/330 [==============================] - 41s 125ms/step - loss: 1.3619 - accuracy: 0.7921 - auc: 0.9553 - precision: 0.8012 - recall: 0.7799
# Epoch 107/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3767 - accuracy: 0.7894 - auc: 0.9546 - precision: 0.8007 - recall: 0.7773
# Epoch 108/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3771 - accuracy: 0.7877 - auc: 0.9550 - precision: 0.7998 - recall: 0.7739
# Epoch 109/500
# 330/330 [==============================] - 41s 126ms/step - loss: 1.3809 - accuracy: 0.7928 - auc: 0.9557 - precision: 0.8044 - recall: 0.7771
# Epoch 110/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3663 - accuracy: 0.7932 - auc: 0.9556 - precision: 0.8030 - recall: 0.7811
# Epoch 111/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3748 - accuracy: 0.7947 - auc: 0.9552 - precision: 0.8054 - recall: 0.7803
# Epoch 112/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3777 - accuracy: 0.7951 - auc: 0.9554 - precision: 0.8039 - recall: 0.7809
# Epoch 113/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3844 - accuracy: 0.7921 - auc: 0.9548 - precision: 0.8033 - recall: 0.7773
# Epoch 114/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3722 - accuracy: 0.7894 - auc: 0.9552 - precision: 0.7991 - recall: 0.7765
# Epoch 115/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3709 - accuracy: 0.7911 - auc: 0.9551 - precision: 0.8024 - recall: 0.7767
# Epoch 116/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3715 - accuracy: 0.7860 - auc: 0.9550 - precision: 0.7957 - recall: 0.7712
# Epoch 117/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.4027 - accuracy: 0.7877 - auc: 0.9540 - precision: 0.7973 - recall: 0.7716
# Epoch 118/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3664 - accuracy: 0.7879 - auc: 0.9549 - precision: 0.7970 - recall: 0.7739
# Epoch 119/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3646 - accuracy: 0.7926 - auc: 0.9560 - precision: 0.8035 - recall: 0.7790
# Epoch 120/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3472 - accuracy: 0.7951 - auc: 0.9562 - precision: 0.8051 - recall: 0.7813
# Epoch 121/500
# 330/330 [==============================] - 41s 125ms/step - loss: 1.3669 - accuracy: 0.7864 - auc: 0.9549 - precision: 0.7998 - recall: 0.7739
# Epoch 122/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3841 - accuracy: 0.7938 - auc: 0.9550 - precision: 0.8008 - recall: 0.7758
# Epoch 123/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3823 - accuracy: 0.7854 - auc: 0.9546 - precision: 0.7964 - recall: 0.7731
# Epoch 124/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.4081 - accuracy: 0.7913 - auc: 0.9536 - precision: 0.8027 - recall: 0.7779
# Epoch 125/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3741 - accuracy: 0.7913 - auc: 0.9543 - precision: 0.8029 - recall: 0.7773
# Epoch 126/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3775 - accuracy: 0.7908 - auc: 0.9548 - precision: 0.7982 - recall: 0.7762
# Epoch 127/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3959 - accuracy: 0.7900 - auc: 0.9539 - precision: 0.7996 - recall: 0.7781
# Epoch 128/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3882 - accuracy: 0.7879 - auc: 0.9544 - precision: 0.7969 - recall: 0.7756
# Epoch 129/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3832 - accuracy: 0.7911 - auc: 0.9552 - precision: 0.7991 - recall: 0.7779
# Epoch 130/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3961 - accuracy: 0.7932 - auc: 0.9557 - precision: 0.8065 - recall: 0.7807
# Epoch 131/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3730 - accuracy: 0.7904 - auc: 0.9555 - precision: 0.8004 - recall: 0.7754
# Epoch 132/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3633 - accuracy: 0.7873 - auc: 0.9556 - precision: 0.8009 - recall: 0.7769
# Epoch 133/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3901 - accuracy: 0.7864 - auc: 0.9549 - precision: 0.7993 - recall: 0.7750
# Epoch 134/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3746 - accuracy: 0.7911 - auc: 0.9539 - precision: 0.8019 - recall: 0.7786
# Epoch 135/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3769 - accuracy: 0.7894 - auc: 0.9556 - precision: 0.7997 - recall: 0.7758
# Epoch 136/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3816 - accuracy: 0.7919 - auc: 0.9548 - precision: 0.8029 - recall: 0.7788
# Epoch 137/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3686 - accuracy: 0.7902 - auc: 0.9558 - precision: 0.8002 - recall: 0.7758
# Epoch 138/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3807 - accuracy: 0.7921 - auc: 0.9546 - precision: 0.8013 - recall: 0.7781
# Epoch 139/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3489 - accuracy: 0.7919 - auc: 0.9553 - precision: 0.8025 - recall: 0.7781
# Epoch 140/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3593 - accuracy: 0.7913 - auc: 0.9557 - precision: 0.8022 - recall: 0.7758
# Epoch 141/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.4033 - accuracy: 0.7830 - auc: 0.9536 - precision: 0.7937 - recall: 0.7676
# Epoch 142/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3536 - accuracy: 0.7928 - auc: 0.9557 - precision: 0.8052 - recall: 0.7805
# Epoch 143/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3732 - accuracy: 0.7932 - auc: 0.9556 - precision: 0.8026 - recall: 0.7775
# Epoch 144/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3623 - accuracy: 0.7870 - auc: 0.9551 - precision: 0.7975 - recall: 0.7741
# Epoch 145/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3428 - accuracy: 0.7945 - auc: 0.9567 - precision: 0.8062 - recall: 0.7796
# Epoch 146/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3483 - accuracy: 0.7890 - auc: 0.9557 - precision: 0.8002 - recall: 0.7735
# Epoch 147/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3635 - accuracy: 0.7911 - auc: 0.9558 - precision: 0.8006 - recall: 0.7792
# Epoch 148/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3359 - accuracy: 0.7889 - auc: 0.9559 - precision: 0.8002 - recall: 0.7775
# Epoch 149/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3573 - accuracy: 0.7947 - auc: 0.9561 - precision: 0.8038 - recall: 0.7782
# Epoch 150/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3973 - accuracy: 0.7925 - auc: 0.9547 - precision: 0.8008 - recall: 0.7750
# Epoch 151/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3753 - accuracy: 0.7961 - auc: 0.9558 - precision: 0.8024 - recall: 0.7820
# Epoch 152/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3631 - accuracy: 0.7944 - auc: 0.9561 - precision: 0.8057 - recall: 0.7822
# Epoch 153/500
# 330/330 [==============================] - 41s 126ms/step - loss: 1.3944 - accuracy: 0.7896 - auc: 0.9542 - precision: 0.7990 - recall: 0.7769
# Epoch 154/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3685 - accuracy: 0.7909 - auc: 0.9550 - precision: 0.7998 - recall: 0.7760
# Epoch 155/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3729 - accuracy: 0.7870 - auc: 0.9554 - precision: 0.8002 - recall: 0.7735
# Epoch 156/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3658 - accuracy: 0.7885 - auc: 0.9550 - precision: 0.8002 - recall: 0.7745
# Epoch 157/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3370 - accuracy: 0.7909 - auc: 0.9559 - precision: 0.7999 - recall: 0.7765
# Epoch 158/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3671 - accuracy: 0.7949 - auc: 0.9556 - precision: 0.8039 - recall: 0.7815
# Epoch 159/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3882 - accuracy: 0.7879 - auc: 0.9538 - precision: 0.8000 - recall: 0.7739
# Epoch 160/500
# 330/330 [==============================] - 41s 125ms/step - loss: 1.3636 - accuracy: 0.7932 - auc: 0.9547 - precision: 0.8026 - recall: 0.7790
# Epoch 161/500
# 330/330 [==============================] - 40s 123ms/step - loss: 1.3693 - accuracy: 0.7898 - auc: 0.9556 - precision: 0.8007 - recall: 0.7752
# Epoch 162/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3788 - accuracy: 0.7926 - auc: 0.9547 - precision: 0.8022 - recall: 0.7794
# Epoch 163/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3707 - accuracy: 0.7896 - auc: 0.9552 - precision: 0.7995 - recall: 0.7745
# Epoch 164/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3863 - accuracy: 0.7906 - auc: 0.9547 - precision: 0.8011 - recall: 0.7777
# Epoch 165/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3811 - accuracy: 0.7892 - auc: 0.9555 - precision: 0.8003 - recall: 0.7746
# Epoch 166/500
# 330/330 [==============================] - 40s 123ms/step - loss: 1.3583 - accuracy: 0.7940 - auc: 0.9552 - precision: 0.8026 - recall: 0.7792
# Epoch 167/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3612 - accuracy: 0.7904 - auc: 0.9554 - precision: 0.7985 - recall: 0.7782
# Epoch 168/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3817 - accuracy: 0.7871 - auc: 0.9543 - precision: 0.7972 - recall: 0.7746
# Epoch 169/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3776 - accuracy: 0.7892 - auc: 0.9547 - precision: 0.8004 - recall: 0.7762
# Epoch 170/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3784 - accuracy: 0.7889 - auc: 0.9553 - precision: 0.7974 - recall: 0.7750
# Epoch 171/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3958 - accuracy: 0.7911 - auc: 0.9538 - precision: 0.8004 - recall: 0.7769
# Epoch 172/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3622 - accuracy: 0.7909 - auc: 0.9554 - precision: 0.8023 - recall: 0.7775
# Epoch 173/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3625 - accuracy: 0.7919 - auc: 0.9556 - precision: 0.8000 - recall: 0.7788
# Epoch 174/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3640 - accuracy: 0.7898 - auc: 0.9553 - precision: 0.8009 - recall: 0.7777
# Epoch 175/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3860 - accuracy: 0.7889 - auc: 0.9544 - precision: 0.8017 - recall: 0.7754
# Epoch 176/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3500 - accuracy: 0.7906 - auc: 0.9556 - precision: 0.8007 - recall: 0.7777
# Epoch 177/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3725 - accuracy: 0.7932 - auc: 0.9554 - precision: 0.8028 - recall: 0.7779
# Epoch 178/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3592 - accuracy: 0.7938 - auc: 0.9555 - precision: 0.8037 - recall: 0.7790
# Epoch 179/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3495 - accuracy: 0.7930 - auc: 0.9554 - precision: 0.8010 - recall: 0.7773
# Epoch 180/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3820 - accuracy: 0.7875 - auc: 0.9547 - precision: 0.7986 - recall: 0.7741
# Epoch 181/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3951 - accuracy: 0.7919 - auc: 0.9545 - precision: 0.8024 - recall: 0.7788
# Epoch 182/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3427 - accuracy: 0.7962 - auc: 0.9567 - precision: 0.8069 - recall: 0.7834
# Epoch 183/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3840 - accuracy: 0.7890 - auc: 0.9548 - precision: 0.8018 - recall: 0.7762
# Epoch 184/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3727 - accuracy: 0.7921 - auc: 0.9553 - precision: 0.8031 - recall: 0.7794
# Epoch 185/500
# 330/330 [==============================] - 41s 125ms/step - loss: 1.3406 - accuracy: 0.7961 - auc: 0.9565 - precision: 0.8054 - recall: 0.7822
# Epoch 186/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3576 - accuracy: 0.7940 - auc: 0.9557 - precision: 0.8043 - recall: 0.7805
# Epoch 187/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3812 - accuracy: 0.7917 - auc: 0.9551 - precision: 0.8015 - recall: 0.7769
# Epoch 188/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3665 - accuracy: 0.7926 - auc: 0.9555 - precision: 0.8040 - recall: 0.7765
# Epoch 189/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3644 - accuracy: 0.7921 - auc: 0.9551 - precision: 0.8000 - recall: 0.7786
# Epoch 190/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3557 - accuracy: 0.7904 - auc: 0.9553 - precision: 0.8000 - recall: 0.7769
# Epoch 191/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3709 - accuracy: 0.7881 - auc: 0.9541 - precision: 0.7998 - recall: 0.7745
# Epoch 192/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3730 - accuracy: 0.7892 - auc: 0.9547 - precision: 0.7985 - recall: 0.7729
# Epoch 193/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3789 - accuracy: 0.7898 - auc: 0.9552 - precision: 0.8023 - recall: 0.7779
# Epoch 194/500
# 330/330 [==============================] - 41s 125ms/step - loss: 1.3674 - accuracy: 0.7890 - auc: 0.9551 - precision: 0.8000 - recall: 0.7746
# Epoch 195/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3540 - accuracy: 0.7915 - auc: 0.9550 - precision: 0.8002 - recall: 0.7788
# Epoch 196/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3652 - accuracy: 0.7942 - auc: 0.9559 - precision: 0.8052 - recall: 0.7818
# Epoch 197/500
# 330/330 [==============================] - 42s 126ms/step - loss: 1.3755 - accuracy: 0.7904 - auc: 0.9547 - precision: 0.8015 - recall: 0.7760
# Epoch 198/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3543 - accuracy: 0.7938 - auc: 0.9562 - precision: 0.8018 - recall: 0.7775
# Epoch 199/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3597 - accuracy: 0.7900 - auc: 0.9555 - precision: 0.8012 - recall: 0.7762
# Epoch 200/500
# 330/330 [==============================] - 41s 125ms/step - loss: 1.3698 - accuracy: 0.7913 - auc: 0.9546 - precision: 0.7995 - recall: 0.7779
# Epoch 201/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3656 - accuracy: 0.7896 - auc: 0.9550 - precision: 0.8004 - recall: 0.7760
# Epoch 202/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3703 - accuracy: 0.7928 - auc: 0.9558 - precision: 0.8045 - recall: 0.7801
# Epoch 203/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3525 - accuracy: 0.7919 - auc: 0.9557 - precision: 0.8012 - recall: 0.7777
# Epoch 204/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3993 - accuracy: 0.7887 - auc: 0.9541 - precision: 0.7978 - recall: 0.7708
# Epoch 205/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3830 - accuracy: 0.7909 - auc: 0.9544 - precision: 0.8011 - recall: 0.7756
# Epoch 206/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3831 - accuracy: 0.7881 - auc: 0.9545 - precision: 0.7970 - recall: 0.7745
# Epoch 207/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3378 - accuracy: 0.7962 - auc: 0.9564 - precision: 0.8047 - recall: 0.7796
# Epoch 208/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3957 - accuracy: 0.7908 - auc: 0.9542 - precision: 0.8017 - recall: 0.7771
# Epoch 209/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3728 - accuracy: 0.7860 - auc: 0.9546 - precision: 0.7962 - recall: 0.7710
# Epoch 210/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3683 - accuracy: 0.7892 - auc: 0.9548 - precision: 0.8000 - recall: 0.77778s - loss: 1.3917 -
# Epoch 211/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3702 - accuracy: 0.7906 - auc: 0.9553 - precision: 0.8007 - recall: 0.7750
# Epoch 212/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3515 - accuracy: 0.7843 - auc: 0.9559 - precision: 0.7956 - recall: 0.7693
# Epoch 213/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3726 - accuracy: 0.7843 - auc: 0.9545 - precision: 0.7955 - recall: 0.7722
# Epoch 214/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3310 - accuracy: 0.7951 - auc: 0.9569 - precision: 0.8039 - recall: 0.7796
# Epoch 215/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3563 - accuracy: 0.7875 - auc: 0.9557 - precision: 0.7970 - recall: 0.7739
# Epoch 216/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3902 - accuracy: 0.7921 - auc: 0.9552 - precision: 0.8022 - recall: 0.7773
# Epoch 217/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3858 - accuracy: 0.7902 - auc: 0.9547 - precision: 0.7999 - recall: 0.7767
# Epoch 218/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3740 - accuracy: 0.7894 - auc: 0.9546 - precision: 0.8005 - recall: 0.7758
# Epoch 219/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3679 - accuracy: 0.7926 - auc: 0.9550 - precision: 0.8044 - recall: 0.7788
# Epoch 220/500
# 330/330 [==============================] - 41s 125ms/step - loss: 1.3945 - accuracy: 0.7909 - auc: 0.9538 - precision: 0.8019 - recall: 0.7773
# Epoch 221/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3777 - accuracy: 0.7919 - auc: 0.9546 - precision: 0.7994 - recall: 0.7758
# Epoch 222/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3871 - accuracy: 0.7889 - auc: 0.9547 - precision: 0.8005 - recall: 0.7743
# Epoch 223/500
# 330/330 [==============================] - 41s 125ms/step - loss: 1.3641 - accuracy: 0.7925 - auc: 0.9549 - precision: 0.8032 - recall: 0.7818
# Epoch 224/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3690 - accuracy: 0.7947 - auc: 0.9561 - precision: 0.8052 - recall: 0.7817
# Epoch 225/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3874 - accuracy: 0.7930 - auc: 0.9545 - precision: 0.8030 - recall: 0.7801
# Epoch 226/500
# 330/330 [==============================] - 41s 125ms/step - loss: 1.3509 - accuracy: 0.7873 - auc: 0.9558 - precision: 0.7982 - recall: 0.7752
# Epoch 227/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3888 - accuracy: 0.7881 - auc: 0.9545 - precision: 0.7985 - recall: 0.7729
# Epoch 228/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3933 - accuracy: 0.7904 - auc: 0.9539 - precision: 0.7990 - recall: 0.7760
# Epoch 229/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3719 - accuracy: 0.7904 - auc: 0.9553 - precision: 0.8016 - recall: 0.7781
# Epoch 230/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3749 - accuracy: 0.7925 - auc: 0.9554 - precision: 0.8016 - recall: 0.7788
# Epoch 231/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3771 - accuracy: 0.7945 - auc: 0.9545 - precision: 0.8025 - recall: 0.7801
# Epoch 232/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3755 - accuracy: 0.7890 - auc: 0.9553 - precision: 0.7991 - recall: 0.7718
# Epoch 233/500
# 330/330 [==============================] - 42s 128ms/step - loss: 1.3894 - accuracy: 0.7879 - auc: 0.9543 - precision: 0.7988 - recall: 0.7763
# Epoch 234/500
# 330/330 [==============================] - 42s 127ms/step - loss: 1.3730 - accuracy: 0.7913 - auc: 0.9549 - precision: 0.8008 - recall: 0.7786
# Epoch 235/500
# 330/330 [==============================] - 41s 125ms/step - loss: 1.3599 - accuracy: 0.7885 - auc: 0.9559 - precision: 0.8001 - recall: 0.7754
# Epoch 236/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3628 - accuracy: 0.7917 - auc: 0.9550 - precision: 0.8011 - recall: 0.7781
# Epoch 237/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3733 - accuracy: 0.7925 - auc: 0.9556 - precision: 0.8041 - recall: 0.7788
# Epoch 238/500
# 330/330 [==============================] - 41s 125ms/step - loss: 1.3738 - accuracy: 0.7900 - auc: 0.9553 - precision: 0.8009 - recall: 0.7763
# Epoch 239/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3618 - accuracy: 0.7892 - auc: 0.9553 - precision: 0.8004 - recall: 0.7739
# Epoch 240/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3662 - accuracy: 0.7923 - auc: 0.9562 - precision: 0.8033 - recall: 0.77792s - loss: 1.3705 - accuracy: 0.7909 - auc: 0.9561 - precision: 0.80
# Epoch 241/500
# 330/330 [==============================] - 41s 125ms/step - loss: 1.3678 - accuracy: 0.7917 - auc: 0.9553 - precision: 0.8032 - recall: 0.7781
# Epoch 242/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.4028 - accuracy: 0.7911 - auc: 0.9543 - precision: 0.8004 - recall: 0.7750
# Epoch 243/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3587 - accuracy: 0.7911 - auc: 0.9557 - precision: 0.8015 - recall: 0.7760
# Epoch 244/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3800 - accuracy: 0.7879 - auc: 0.9547 - precision: 0.7981 - recall: 0.7739
# Epoch 245/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3826 - accuracy: 0.7854 - auc: 0.9546 - precision: 0.7987 - recall: 0.7722
# Epoch 246/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3582 - accuracy: 0.7890 - auc: 0.9556 - precision: 0.8031 - recall: 0.7760
# Epoch 247/500
# 330/330 [==============================] - 41s 125ms/step - loss: 1.3811 - accuracy: 0.7951 - auc: 0.9544 - precision: 0.8047 - recall: 0.7799
# Epoch 248/500
# 330/330 [==============================] - 41s 125ms/step - loss: 1.3781 - accuracy: 0.7945 - auc: 0.9546 - precision: 0.8025 - recall: 0.7794
# Epoch 249/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.4137 - accuracy: 0.7904 - auc: 0.9542 - precision: 0.8018 - recall: 0.7746
# Epoch 250/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3453 - accuracy: 0.7928 - auc: 0.9565 - precision: 0.8023 - recall: 0.7760
# Epoch 251/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3711 - accuracy: 0.7894 - auc: 0.9549 - precision: 0.8007 - recall: 0.7758
# Epoch 252/500
# 330/330 [==============================] - 41s 125ms/step - loss: 1.3760 - accuracy: 0.7911 - auc: 0.9550 - precision: 0.8015 - recall: 0.7750
# Epoch 253/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3786 - accuracy: 0.7892 - auc: 0.9545 - precision: 0.7993 - recall: 0.7754
# Epoch 254/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3797 - accuracy: 0.7889 - auc: 0.9549 - precision: 0.7978 - recall: 0.7739
# Epoch 255/500
# 330/330 [==============================] - 41s 125ms/step - loss: 1.3768 - accuracy: 0.7877 - auc: 0.9548 - precision: 0.7992 - recall: 0.7731
# Epoch 256/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3402 - accuracy: 0.7936 - auc: 0.9564 - precision: 0.8057 - recall: 0.7790
# Epoch 257/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3767 - accuracy: 0.7889 - auc: 0.9547 - precision: 0.7982 - recall: 0.7745
# Epoch 258/500
# 330/330 [==============================] - 41s 125ms/step - loss: 1.3634 - accuracy: 0.7940 - auc: 0.9552 - precision: 0.8043 - recall: 0.7796
# Epoch 259/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3915 - accuracy: 0.7900 - auc: 0.9548 - precision: 0.8018 - recall: 0.7760
# Epoch 260/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3983 - accuracy: 0.7879 - auc: 0.9548 - precision: 0.7996 - recall: 0.7739
# Epoch 261/500
# 330/330 [==============================] - 41s 125ms/step - loss: 1.3606 - accuracy: 0.7934 - auc: 0.9554 - precision: 0.8020 - recall: 0.7786
# Epoch 262/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3679 - accuracy: 0.7868 - auc: 0.9555 - precision: 0.7986 - recall: 0.7705
# Epoch 263/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3717 - accuracy: 0.7881 - auc: 0.9552 - precision: 0.7992 - recall: 0.7731
# Epoch 264/500
# 330/330 [==============================] - 41s 125ms/step - loss: 1.3838 - accuracy: 0.7873 - auc: 0.9548 - precision: 0.7981 - recall: 0.7748
# Epoch 265/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3576 - accuracy: 0.7938 - auc: 0.9557 - precision: 0.8029 - recall: 0.7792
# Epoch 266/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3453 - accuracy: 0.7959 - auc: 0.9566 - precision: 0.8034 - recall: 0.7784
# Epoch 267/500
# 330/330 [==============================] - 41s 125ms/step - loss: 1.3812 - accuracy: 0.7945 - auc: 0.9549 - precision: 0.8044 - recall: 0.7809
# Epoch 268/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3654 - accuracy: 0.7959 - auc: 0.9555 - precision: 0.8060 - recall: 0.7820
# Epoch 269/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3506 - accuracy: 0.7926 - auc: 0.9554 - precision: 0.8029 - recall: 0.7790
# Epoch 270/500
# 330/330 [==============================] - 41s 125ms/step - loss: 1.3608 - accuracy: 0.7887 - auc: 0.9554 - precision: 0.7984 - recall: 0.7739
# Epoch 271/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3389 - accuracy: 0.7951 - auc: 0.9565 - precision: 0.8042 - recall: 0.7826
# Epoch 272/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3761 - accuracy: 0.7898 - auc: 0.9553 - precision: 0.8013 - recall: 0.7752
# Epoch 273/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3685 - accuracy: 0.7942 - auc: 0.9555 - precision: 0.8042 - recall: 0.7786
# Epoch 274/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3920 - accuracy: 0.7879 - auc: 0.9544 - precision: 0.7998 - recall: 0.7752
# Epoch 275/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3956 - accuracy: 0.7898 - auc: 0.9552 - precision: 0.8058 - recall: 0.7756
# Epoch 276/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3611 - accuracy: 0.7968 - auc: 0.9557 - precision: 0.8074 - recall: 0.7824
# Epoch 277/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3622 - accuracy: 0.7879 - auc: 0.9553 - precision: 0.8009 - recall: 0.7762
# Epoch 278/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3688 - accuracy: 0.7879 - auc: 0.9539 - precision: 0.7971 - recall: 0.7758
# Epoch 279/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3874 - accuracy: 0.7864 - auc: 0.9544 - precision: 0.7978 - recall: 0.7727
# Epoch 280/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3587 - accuracy: 0.7930 - auc: 0.9547 - precision: 0.8022 - recall: 0.7779
# Epoch 281/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3950 - accuracy: 0.7909 - auc: 0.9545 - precision: 0.7991 - recall: 0.7781
# Epoch 282/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3844 - accuracy: 0.7932 - auc: 0.9542 - precision: 0.8027 - recall: 0.7796
# Epoch 283/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3869 - accuracy: 0.7885 - auc: 0.9549 - precision: 0.7978 - recall: 0.7727
# Epoch 284/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3533 - accuracy: 0.7938 - auc: 0.9559 - precision: 0.8052 - recall: 0.7773
# Epoch 285/500
# 330/330 [==============================] - 41s 125ms/step - loss: 1.3805 - accuracy: 0.7890 - auc: 0.9546 - precision: 0.8035 - recall: 0.7773
# Epoch 286/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3829 - accuracy: 0.7932 - auc: 0.9558 - precision: 0.8020 - recall: 0.7786
# Epoch 287/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3636 - accuracy: 0.7934 - auc: 0.9549 - precision: 0.8015 - recall: 0.7777
# Epoch 288/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3481 - accuracy: 0.7936 - auc: 0.9559 - precision: 0.8024 - recall: 0.7796
# Epoch 289/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3665 - accuracy: 0.7900 - auc: 0.9552 - precision: 0.8017 - recall: 0.7777
# Epoch 290/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3731 - accuracy: 0.7913 - auc: 0.9547 - precision: 0.8005 - recall: 0.7794
# Epoch 291/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3695 - accuracy: 0.7925 - auc: 0.9548 - precision: 0.8025 - recall: 0.7799
# Epoch 292/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3873 - accuracy: 0.7830 - auc: 0.9538 - precision: 0.7962 - recall: 0.7691
# Epoch 293/500
# 330/330 [==============================] - 41s 125ms/step - loss: 1.3849 - accuracy: 0.7879 - auc: 0.9546 - precision: 0.7984 - recall: 0.7737
# Epoch 294/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3682 - accuracy: 0.7930 - auc: 0.9552 - precision: 0.8040 - recall: 0.7788
# Epoch 295/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3764 - accuracy: 0.7911 - auc: 0.9548 - precision: 0.8026 - recall: 0.7782
# Epoch 296/500
# 330/330 [==============================] - 41s 125ms/step - loss: 1.3646 - accuracy: 0.7930 - auc: 0.9552 - precision: 0.8017 - recall: 0.7792
# Epoch 297/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3491 - accuracy: 0.7953 - auc: 0.9563 - precision: 0.8048 - recall: 0.7798
# Epoch 298/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3787 - accuracy: 0.7921 - auc: 0.9550 - precision: 0.8016 - recall: 0.7786
# Epoch 299/500
# 330/330 [==============================] - 41s 125ms/step - loss: 1.3876 - accuracy: 0.7944 - auc: 0.9548 - precision: 0.8031 - recall: 0.7794
# Epoch 300/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3995 - accuracy: 0.7875 - auc: 0.9540 - precision: 0.8001 - recall: 0.7752
# Epoch 301/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3614 - accuracy: 0.7976 - auc: 0.9558 - precision: 0.8056 - recall: 0.7809
# Epoch 302/500
# 330/330 [==============================] - 41s 125ms/step - loss: 1.3572 - accuracy: 0.7909 - auc: 0.9558 - precision: 0.8024 - recall: 0.7781
# Epoch 303/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3844 - accuracy: 0.7890 - auc: 0.9540 - precision: 0.7996 - recall: 0.7754
# Epoch 304/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3808 - accuracy: 0.7883 - auc: 0.9549 - precision: 0.7995 - recall: 0.7741
# Epoch 305/500
# 330/330 [==============================] - 41s 125ms/step - loss: 1.3812 - accuracy: 0.7911 - auc: 0.9552 - precision: 0.7999 - recall: 0.7796
# Epoch 306/500
# ...
# Epoch 400/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3851 - accuracy: 0.7854 - auc: 0.9558 - precision: 0.7984 - recall: 0.7745
# Epoch 401/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3461 - accuracy: 0.7968 - auc: 0.9559 - precision: 0.8075 - recall: 0.7845
# Epoch 402/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3638 - accuracy: 0.7879 - auc: 0.9552 - precision: 0.7970 - recall: 0.7760
# Epoch 403/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3406 - accuracy: 0.8002 - auc: 0.9571 - precision: 0.8101 - recall: 0.7873
# Epoch 404/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3732 - accuracy: 0.7947 - auc: 0.9550 - precision: 0.8050 - recall: 0.7826
# Epoch 405/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3590 - accuracy: 0.7900 - auc: 0.9549 - precision: 0.8000 - recall: 0.7756
# Epoch 406/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3873 - accuracy: 0.7856 - auc: 0.9545 - precision: 0.7954 - recall: 0.7735
# Epoch 407/500
# 330/330 [==============================] - 41s 125ms/step - loss: 1.3737 - accuracy: 0.7845 - auc: 0.9546 - precision: 0.7963 - recall: 0.7697
# Epoch 408/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3683 - accuracy: 0.7909 - auc: 0.9559 - precision: 0.8013 - recall: 0.7788
# Epoch 409/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3501 - accuracy: 0.7932 - auc: 0.9554 - precision: 0.8047 - recall: 0.7811
# Epoch 410/500
# 330/330 [==============================] - 41s 125ms/step - loss: 1.3686 - accuracy: 0.7856 - auc: 0.9552 - precision: 0.7960 - recall: 0.7727
# Epoch 411/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3638 - accuracy: 0.7904 - auc: 0.9553 - precision: 0.8025 - recall: 0.7762
# Epoch 412/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3677 - accuracy: 0.7915 - auc: 0.9556 - precision: 0.8016 - recall: 0.7790
# Epoch 413/500
# 330/330 [==============================] - 41s 125ms/step - loss: 1.3779 - accuracy: 0.7919 - auc: 0.9543 - precision: 0.8013 - recall: 0.7760
# Epoch 414/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3697 - accuracy: 0.7906 - auc: 0.9549 - precision: 0.8019 - recall: 0.7773
# Epoch 415/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3672 - accuracy: 0.7949 - auc: 0.9557 - precision: 0.8061 - recall: 0.7807
# Epoch 416/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3809 - accuracy: 0.7862 - auc: 0.9542 - precision: 0.7961 - recall: 0.7695
# Epoch 417/500
# 330/330 [==============================] - 41s 125ms/step - loss: 1.3849 - accuracy: 0.7908 - auc: 0.9549 - precision: 0.8004 - recall: 0.7784
# Epoch 418/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3688 - accuracy: 0.7923 - auc: 0.9554 - precision: 0.8029 - recall: 0.7784
# Epoch 419/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3911 - accuracy: 0.7890 - auc: 0.9558 - precision: 0.8011 - recall: 0.7763
# Epoch 420/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3943 - accuracy: 0.7892 - auc: 0.9545 - precision: 0.7971 - recall: 0.7758
# Epoch 421/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3766 - accuracy: 0.7849 - auc: 0.9544 - precision: 0.7977 - recall: 0.7722
# Epoch 422/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3649 - accuracy: 0.7917 - auc: 0.9554 - precision: 0.8020 - recall: 0.7777
# Epoch 423/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3847 - accuracy: 0.7904 - auc: 0.9540 - precision: 0.8013 - recall: 0.7767
# Epoch 424/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3638 - accuracy: 0.7913 - auc: 0.9554 - precision: 0.8015 - recall: 0.7752
# Epoch 425/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3699 - accuracy: 0.7889 - auc: 0.9554 - precision: 0.7995 - recall: 0.7739
# Epoch 426/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3661 - accuracy: 0.7892 - auc: 0.9549 - precision: 0.7995 - recall: 0.7760
# Epoch 427/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3671 - accuracy: 0.7889 - auc: 0.9554 - precision: 0.8010 - recall: 0.7743
# Epoch 428/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3467 - accuracy: 0.7934 - auc: 0.9563 - precision: 0.8017 - recall: 0.7746
# Epoch 429/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3789 - accuracy: 0.7955 - auc: 0.9549 - precision: 0.8027 - recall: 0.7801
# Epoch 430/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3727 - accuracy: 0.7898 - auc: 0.9544 - precision: 0.7999 - recall: 0.7765
# Epoch 431/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3712 - accuracy: 0.7879 - auc: 0.9546 - precision: 0.8005 - recall: 0.7737
# Epoch 432/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.4000 - accuracy: 0.7900 - auc: 0.9537 - precision: 0.8012 - recall: 0.7777
# Epoch 433/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3670 - accuracy: 0.7873 - auc: 0.9548 - precision: 0.7987 - recall: 0.7754
# Epoch 434/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3800 - accuracy: 0.7862 - auc: 0.9538 - precision: 0.7944 - recall: 0.7703
# Epoch 435/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3546 - accuracy: 0.7913 - auc: 0.9555 - precision: 0.8028 - recall: 0.7762
# Epoch 436/500
# 330/330 [==============================] - 41s 125ms/step - loss: 1.3719 - accuracy: 0.7942 - auc: 0.9558 - precision: 0.8057 - recall: 0.7781
# Epoch 437/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3705 - accuracy: 0.7854 - auc: 0.9546 - precision: 0.7946 - recall: 0.7707
# Epoch 438/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3674 - accuracy: 0.7909 - auc: 0.9549 - precision: 0.7999 - recall: 0.7773
# Epoch 439/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3954 - accuracy: 0.7856 - auc: 0.9540 - precision: 0.7949 - recall: 0.7707
# Epoch 440/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3961 - accuracy: 0.7934 - auc: 0.9546 - precision: 0.8028 - recall: 0.7796
# Epoch 441/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3937 - accuracy: 0.7887 - auc: 0.9556 - precision: 0.7985 - recall: 0.7788
# Epoch 442/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3758 - accuracy: 0.7856 - auc: 0.9557 - precision: 0.7974 - recall: 0.7729
# Epoch 443/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3619 - accuracy: 0.7871 - auc: 0.9551 - precision: 0.7962 - recall: 0.7739
# Epoch 444/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.4052 - accuracy: 0.7847 - auc: 0.9536 - precision: 0.7965 - recall: 0.7693
# Epoch 445/500
# 330/330 [==============================] - 41s 125ms/step - loss: 1.3663 - accuracy: 0.7909 - auc: 0.9560 - precision: 0.8038 - recall: 0.7786
# Epoch 446/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3695 - accuracy: 0.7921 - auc: 0.9555 - precision: 0.8036 - recall: 0.7784
# Epoch 447/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3820 - accuracy: 0.7862 - auc: 0.9541 - precision: 0.7970 - recall: 0.7724
# Epoch 448/500
# 330/330 [==============================] - 41s 125ms/step - loss: 1.3728 - accuracy: 0.7875 - auc: 0.9552 - precision: 0.8006 - recall: 0.7754
# Epoch 449/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3854 - accuracy: 0.7849 - auc: 0.9546 - precision: 0.7972 - recall: 0.7726
# Epoch 450/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3761 - accuracy: 0.7925 - auc: 0.9552 - precision: 0.8027 - recall: 0.7773
# Epoch 451/500
# 330/330 [==============================] - 41s 125ms/step - loss: 1.3960 - accuracy: 0.7889 - auc: 0.9544 - precision: 0.7987 - recall: 0.7754
# Epoch 452/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3836 - accuracy: 0.7871 - auc: 0.9544 - precision: 0.7976 - recall: 0.7737
# Epoch 453/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3621 - accuracy: 0.7932 - auc: 0.9563 - precision: 0.8047 - recall: 0.7781
# Epoch 454/500
# 330/330 [==============================] - 41s 125ms/step - loss: 1.3582 - accuracy: 0.7853 - auc: 0.9548 - precision: 0.7950 - recall: 0.7688
# Epoch 455/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3568 - accuracy: 0.7932 - auc: 0.9555 - precision: 0.8009 - recall: 0.7771
# Epoch 456/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3562 - accuracy: 0.7940 - auc: 0.9554 - precision: 0.8037 - recall: 0.7813
# Epoch 457/500
# 330/330 [==============================] - 41s 125ms/step - loss: 1.3503 - accuracy: 0.7908 - auc: 0.9558 - precision: 0.8024 - recall: 0.7750
# Epoch 458/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3607 - accuracy: 0.7911 - auc: 0.9547 - precision: 0.8019 - recall: 0.7794
# Epoch 459/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3658 - accuracy: 0.7915 - auc: 0.9559 - precision: 0.8014 - recall: 0.7788
# Epoch 460/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.4151 - accuracy: 0.7949 - auc: 0.9544 - precision: 0.8036 - recall: 0.7832
# Epoch 461/500
# 330/330 [==============================] - 41s 125ms/step - loss: 1.3729 - accuracy: 0.7923 - auc: 0.9551 - precision: 0.8028 - recall: 0.7792
# Epoch 462/500
# 330/330 [==============================] - 41s 125ms/step - loss: 1.3676 - accuracy: 0.7921 - auc: 0.9553 - precision: 0.8028 - recall: 0.7796
# Epoch 463/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3698 - accuracy: 0.7885 - auc: 0.9552 - precision: 0.8011 - recall: 0.7750
# Epoch 464/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3756 - accuracy: 0.7894 - auc: 0.9547 - precision: 0.7999 - recall: 0.7752
# Epoch 465/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.4091 - accuracy: 0.7902 - auc: 0.9544 - precision: 0.8025 - recall: 0.7773
# Epoch 466/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3542 - accuracy: 0.7879 - auc: 0.9557 - precision: 0.8008 - recall: 0.7801
# Epoch 467/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3876 - accuracy: 0.7902 - auc: 0.9546 - precision: 0.8004 - recall: 0.7765
# Epoch 468/500
# 330/330 [==============================] - 41s 125ms/step - loss: 1.3836 - accuracy: 0.7890 - auc: 0.9545 - precision: 0.7986 - recall: 0.7746
# Epoch 469/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3544 - accuracy: 0.7932 - auc: 0.9558 - precision: 0.8046 - recall: 0.7805
# Epoch 470/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3461 - accuracy: 0.7945 - auc: 0.9558 - precision: 0.8033 - recall: 0.7826
# Epoch 471/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3874 - accuracy: 0.7889 - auc: 0.9542 - precision: 0.8003 - recall: 0.7763
# Epoch 472/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3581 - accuracy: 0.7870 - auc: 0.9555 - precision: 0.7987 - recall: 0.7710
# Epoch 473/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3633 - accuracy: 0.7866 - auc: 0.9556 - precision: 0.7966 - recall: 0.7733
# Epoch 474/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3929 - accuracy: 0.7839 - auc: 0.9541 - precision: 0.7943 - recall: 0.7701
# Epoch 475/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3527 - accuracy: 0.7900 - auc: 0.9556 - precision: 0.8018 - recall: 0.7784
# Epoch 476/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3555 - accuracy: 0.7902 - auc: 0.9556 - precision: 0.8022 - recall: 0.7771
# Epoch 477/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3697 - accuracy: 0.7908 - auc: 0.9553 - precision: 0.8017 - recall: 0.7771
# Epoch 478/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3866 - accuracy: 0.7866 - auc: 0.9543 - precision: 0.8002 - recall: 0.7756
# Epoch 479/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3710 - accuracy: 0.7938 - auc: 0.9561 - precision: 0.8041 - recall: 0.7803
# Epoch 480/500
# 330/330 [==============================] - 41s 125ms/step - loss: 1.3591 - accuracy: 0.7947 - auc: 0.9554 - precision: 0.8045 - recall: 0.7801
# Epoch 481/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3540 - accuracy: 0.7898 - auc: 0.9554 - precision: 0.8006 - recall: 0.7763
# Epoch 482/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3648 - accuracy: 0.7913 - auc: 0.9545 - precision: 0.8000 - recall: 0.7773
# Epoch 483/500
# 330/330 [==============================] - 41s 125ms/step - loss: 1.3849 - accuracy: 0.7868 - auc: 0.9536 - precision: 0.7942 - recall: 0.7741
# Epoch 484/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3661 - accuracy: 0.7887 - auc: 0.9546 - precision: 0.7977 - recall: 0.7748
# Epoch 485/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3823 - accuracy: 0.7923 - auc: 0.9560 - precision: 0.8036 - recall: 0.7784
# Epoch 486/500
# 330/330 [==============================] - 41s 125ms/step - loss: 1.3962 - accuracy: 0.7945 - auc: 0.9545 - precision: 0.8035 - recall: 0.7805
# Epoch 487/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3685 - accuracy: 0.7883 - auc: 0.9547 - precision: 0.8008 - recall: 0.7720
# Epoch 488/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3683 - accuracy: 0.7917 - auc: 0.9547 - precision: 0.7993 - recall: 0.7765
# Epoch 489/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3729 - accuracy: 0.7889 - auc: 0.9543 - precision: 0.7982 - recall: 0.7746
# Epoch 490/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3787 - accuracy: 0.7917 - auc: 0.9549 - precision: 0.7998 - recall: 0.7777
# Epoch 491/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3661 - accuracy: 0.7904 - auc: 0.9545 - precision: 0.7998 - recall: 0.7779
# Epoch 492/500
# 330/330 [==============================] - 41s 125ms/step - loss: 1.3902 - accuracy: 0.7913 - auc: 0.9548 - precision: 0.8017 - recall: 0.7786
# Epoch 493/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3714 - accuracy: 0.7896 - auc: 0.9555 - precision: 0.8018 - recall: 0.7760
# Epoch 494/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3864 - accuracy: 0.7890 - auc: 0.9546 - precision: 0.8000 - recall: 0.7735
# Epoch 495/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3672 - accuracy: 0.7908 - auc: 0.9550 - precision: 0.8018 - recall: 0.7781
# Epoch 496/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3969 - accuracy: 0.7902 - auc: 0.9545 - precision: 0.8013 - recall: 0.7773
# Epoch 497/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3433 - accuracy: 0.7879 - auc: 0.9559 - precision: 0.8007 - recall: 0.7750
# Epoch 498/500
# 330/330 [==============================] - 41s 124ms/step - loss: 1.3739 - accuracy: 0.7834 - auc: 0.9550 - precision: 0.7938 - recall: 0.7705
# Epoch 499/500
# 330/330 [==============================] - 41s 123ms/step - loss: 1.3490 - accuracy: 0.7925 - auc: 0.9559 - precision: 0.8012 - recall: 0.7769
# Epoch 500/500
# 330/330 [==============================] - 41s 125ms/step - loss: 1.3543 - accuracy: 0.7972 - auc: 0.9564 - precision: 0.8069 - recall: 0.78091s - loss: 1.3524 - accuracy: 0.7986 - auc: 0.9568 - precision: 0.8081

# %%
#Save model

model.save('./Models/Model_seven_with_augmentation_tuned', overwrite = False)
# Out:
# [WARNING] ./Models/Model_seven_with_augmentation_tuned already exists - overwrite? [y/n]n

# %%
#Save history file:

'''
import pickle

with open('./Models/Model_seven_with_augmentation_tuned/history.p', 'wb') as outfile:
    pickle.dump(history, outfile)
'''
# Out:
# "\nimport pickle\n\nwith open('./Models/Model_seven_with_augmentation_tuned/history.p', 'wb') as outfile:\n    pickle.dump(history, outfile)\n"

# %%
#Load history file:

'''
import pickle

#Load main epoch history


with open('./Models/Model_seven_with_augmentation_tuned/history.p', 'rb') as readingfile:
    history = pickle.load(readingfile)
'''
# Out:
# "\nimport pickle\n\n#Load main epoch history\n\n\nwith open('./Models/Model_seven_with_augmentation_tuned/history.p', 'rb') as readingfile:\n    history = pickle.load(readingfile)\n"

# %% [markdown]
# # Evaluate model and see how it performed!

# %%
#Evaluate against test data:

evaluate = model.evaluate(testing_ds)
# Out:
# 20/20 [==============================] - 2s 104ms/step - loss: 0.9888 - accuracy: 0.7595 - auc: 0.8909 - precision: 0.7716 - recall: 0.7215

# %%
#Metrics contained in our training history file:

history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'auc', 'precision', 'recall', 'lr'])

# %%
#Plot the learning rate over epochs:

plt.figure(figsize = (12,7))

plt.plot(history.history['lr'])

plt.title('Learning rate vs Epochs')
plt.ylabel('Learning Rate')
plt.xlabel('Epochs')
plt.show()

# %%
#Plot model accuracy over epochs:

plt.figure(figsize = (12,7))

sns.lineplot(y = history.history['accuracy'], x = np.arange(300,800))

plt.title('Accuracy  vs Epochs')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.show()

# %% [markdown]
# Note: Training history under 300 epochs are in the Keras tuner, but can't seem to access them

# %%
#Plot loss function over epochs:

plt.figure(figsize = (12,7))

sns.lineplot(y = history.history['loss'], x = np.arange(300,800)) #History under 300 epochs are in the tuner, can't seem to access them

plt.title('Loss (Categorical Cross-Entropy) vs Epochs')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.show()

# %% [markdown]
# ### Confusion matrix and classification report:

# %%
#Prepare a test generator with shuffle = False so we can identify the true/predicted classes

test_generator = generator.flow_from_directory(directory = './Pictures/test',
                                                class_mode = 'categorical',
                                                color_mode = 'grayscale',
                                               shuffle = False)

predictions = model.predict(test_generator)

predicted_classes = np.argmax(predictions, axis = 1)
true_classes = test_generator.classes
# Out:
# Found 632 images belonging to 4 classes.

# %%
cm = confusion_matrix(true_classes, predicted_classes)

df_cm = pd.DataFrame(cm,
                     index = class_count.keys(),
                     columns = class_count.keys())

plt.figure(figsize = (15,10))

sns.set(font_scale = 1.3)

sns.heatmap(df_cm, annot = True, cmap = 'Blues')

plt.xlabel('Predicted Labels')
plt.ylabel('True labels')

plt.title('Test data')



plt.show()

# %%
from sklearn.metrics import classification_report

print(classification_report(true_classes, predicted_classes, target_names = class_count.keys()))
# Out:
#                   precision    recall  f1-score   support
#
#         bacteria       0.81      0.94      0.87       242
#         covid-19       0.41      0.88      0.56         8
#           normal       0.93      0.40      0.56       234
# virus(non-covid)       0.55      0.88      0.68       148
#
#         accuracy                           0.72       632
#        macro avg       0.68      0.77      0.67       632
#     weighted avg       0.79      0.72      0.71       632

# %% [markdown]
# # Concluding observations:
#
# The model sucessfully picked up almost all the covid-19 images with an 0.88 recall rate, although albeit there being only 8.
#
# An interesting observation was that the model often mistook normal X-Rays for viral (non-covid) X-rays (96 misclassifications), but almost never the other way around (1 misclassification).
#
# The model also was very successful at identifying bacterial infections with a recall rate of 0.94 (230 out of 245).
